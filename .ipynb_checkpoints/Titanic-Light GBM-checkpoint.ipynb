# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from lightgbm import LGBMClassifier

# %%
#read datasets
testpd = pd.read_csv('/Users/scottgleave/Downloads/DataMiningCourse/Kaggle/Titanic/sys6018-competition-titanic/all/test.csv')
trainpd = pd.read_csv('/Users/scottgleave/Downloads/DataMiningCourse/Kaggle/Titanic/sys6018-competition-titanic/all/train.csv')
trainpd.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#import logistic regression
from sklearn.linear_model import LogisticRegression

# %%
#explore and fill nan
trainpd.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                        Name   Sex  \
# count    891.000000  891.000000  891.000000                         891   891
# unique          NaN         NaN         NaN                         891     2
# top             NaN         NaN         NaN  Carter, Mr. William Ernest  male
# freq            NaN         NaN         NaN                           1   577
# mean     446.000000    0.383838    2.308642                         NaN   NaN
# std      257.353842    0.486592    0.836071                         NaN   NaN
# min        1.000000    0.000000    1.000000                         NaN   NaN
# 25%      223.500000    0.000000    2.000000                         NaN   NaN
# 50%      446.000000    0.000000    3.000000                         NaN   NaN
# 75%      668.500000    1.000000    3.000000                         NaN   NaN
# max      891.000000    1.000000    3.000000                         NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000   204
# unique         NaN         NaN         NaN       681         NaN   147
# top            NaN         NaN         NaN  CA. 2343         NaN    G6
# freq           NaN         NaN         NaN         7         NaN     4
# mean     29.699118    0.523008    0.381594       NaN   32.204208   NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429   NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000   NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400   NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200   NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000   NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200   NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
#Look at where null values
trainpd.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#fill cabin na with 0
trainpd[['Cabin']]=trainpd[['Cabin']].fillna(0)
trainpd.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S

# %%
#create column of test set IDs
testids = testpd['PassengerId']

# %%
#create multiple datasets for target columns
ytrain = trainpd['Survived']
xtrain = trainpd.drop('Survived', axis =1)

# %%
#check if there are any nulls
trainpd[trainpd.isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 61            62         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# 121          122         0       3
# 126          127         0       3
# 128          129         1       3
# 140          141         0       3
# ..           ...       ...     ...
# 727          728         1       3
# 732          733         0       2
# 738          739         0       3
# 739          740         0       3
# 740          741         1       1
# 760          761         0       3
# 766          767         0       1
# 768          769         0       3
# 773          774         0       3
# 776          777         0       3
# 778          779         0       3
# 783          784         0       3
# 790          791         0       3
# 792          793         0       3
# 793          794         0       1
# 815          816         0       1
# 825          826         0       3
# 826          827         0       3
# 828          829         1       3
# 829          830         1       1
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 5                                  Moran, Mr. James    male   NaN      0
# 17                     Williams, Mr. Charles Eugene    male   NaN      0
# 19                          Masselmani, Mrs. Fatima  female   NaN      0
# 26                          Emir, Mr. Farred Chehab    male   NaN      0
# 28                    O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                              Todoroff, Mr. Lalio    male   NaN      0
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                         Glynn, Miss. Mary Agatha  female   NaN      0
# 36                                 Mamee, Mr. Hanna    male   NaN      0
# 42                              Kraeff, Mr. Theodor    male   NaN      0
# 45                         Rogers, Mr. William John    male   NaN      0
# 46                                Lennon, Mr. Denis    male   NaN      1
# 47                        O'Driscoll, Miss. Bridget  female   NaN      0
# 48                              Samaan, Mr. Youssef    male   NaN      2
# 55                                Woolner, Mr. Hugh    male   NaN      0
# 61                              Icard, Miss. Amelie  female  38.0      0
# 64                            Stewart, Mr. Albert A    male   NaN      0
# 65                         Moubarek, Master. Gerios    male   NaN      1
# 76                                Staneff, Mr. Ivan    male   NaN      0
# 77                         Moutal, Mr. Rahamin Haim    male   NaN      0
# 82                   McDermott, Miss. Brigdet Delia  female   NaN      0
# 87                    Slocovski, Mr. Selman Francis    male   NaN      0
# 95                      Shorney, Mr. Charles Joseph    male   NaN      0
# 101                Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
#
# 1287    male  24.0      0      0              371109    7.2500    NaN        Q
# 1289    male  22.0      0      0              347065    7.7750    NaN        S
# 1290    male  31.0      0      0               21332    7.7333    NaN        Q
# 1292    male  38.0      1      0               28664   21.0000    NaN        S
# 1293  female  22.0      0      1              112378   59.4000    NaN        C
# 1294    male  17.0      0      0              113059   47.1000    NaN        S
# 1297    male  23.0      1      0               28666   10.5000    NaN        S
# 1299  female   NaN      0      0              334915    7.7208    NaN        Q
# 1300  female   3.0      1      1  SOTON/O.Q. 3101315   13.7750    NaN        S
# 1301  female   NaN      0      0              365237    7.7500    NaN        Q
# 1303  female  28.0      0      0              347086    7.7750    NaN        S
# 1304    male   NaN      0      0           A.5. 3236    8.0500    NaN        S
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500    NaN        S
# 1307    male   NaN      0      0              359309    8.0500    NaN        S
# 1308    male   NaN      1      1                2668   22.3583    NaN        C
#
# [510 rows x 11 columns]

# %%
#age nan with average
testconcat[['Age']] = testconcat[['Age']].fillna(testconcat.mean())

# %%
#see what nulls remain
testconcat.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         2
# dtype: int64

# %%
#fare with average(only one anyway)
testconcat[['Fare']] = testconcat[['Fare']].fillna(testconcat.mean())

# %%
#fill cabin na with 0
testconcat[['Cabin']] = testconcat[['Cabin']].fillna(0)

# %%
#fill embarked na with 0
testconcat[['Embarked']] = testconcat[['Embarked']].fillna(0)

# %%
#dropping column
testconcat = testconcat.drop(columns=['Name'])

# %%
testconcat.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0            1       3    male  22.0      1      0         A/5 21171   7.2500
# 1            2       1  female  38.0      1      0          PC 17599  71.2833
# 2            3       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3            4       1  female  35.0      1      0            113803  53.1000
# 4            5       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0     0        S
# 1   C85        C
# 2     0        S
# 3  C123        S
# 4     0        S

# %%
#one hot encoding for categorical data
testconcat = pd.get_dummies(testconcat)

# %%
#separate test and train
testlist = testids.tolist()
testfinal = testconcat[testconcat.PassengerId.isin(testlist)] 
trainfinal = testconcat[~testconcat.PassengerId.isin(testlist)]

# %%
#check that same number of columns
print(testfinal.shape, trainfinal.shape)
# Out:
# (418, 1128) (891, 1128)

# %%
#submission to csv
submit.to_csv('TitanicSubmit.csv', index=False)

# %%
clf = LGBMClassifier(
    nthread=4,
    n_estimators=10000,
    learning_rate=0.02,
    num_leaves=34,
    colsample_bytree=0.9497036,
    subsample=0.8715623,
    max_depth=8,
    reg_alpha=0.041545473,
    reg_lambda=0.0735294,
    min_split_gain=0.0222415,
    min_child_weight=39.3259775,
    feature_fraction = .8,
    silent=-1,
    verbose=-1, )

clf.fit(trainfinal, ytrain)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None,
#         colsample_bytree=0.9497036, feature_fraction=0.8,
#         learning_rate=0.02, max_depth=8, min_child_samples=20,
#         min_child_weight=39.3259775, min_split_gain=0.0222415,
#         n_estimators=10000, n_jobs=-1, nthread=4, num_leaves=34,
#         objective=None, random_state=None, reg_alpha=0.041545473,
#         reg_lambda=0.0735294, silent=-1, subsample=0.8715623,
#         subsample_for_bin=200000, subsample_freq=0, verbose=-1)

# %%
y_pred = clf.predict(testfinal)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
testlist = np.asarray(testlist)
submit = pd.DataFrame(y_pred)

# %%
submit["PassengerId"] = testlist

# %%
submit.columns = ['Survived', 'PassengerId']

# %%
submit = submit[['PassengerId', 'Survived']]

# %%
submit.to_csv('TitanicSubmitgbm.csv', index=False)
